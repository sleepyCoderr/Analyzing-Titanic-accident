# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
titanic_df=pd.read_csv('train.csv')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
titanic_df["Age"].mean()
# Out:
# 29.69911764705882

# %%
titanic_df.sort_values('Age',ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 630          631         1       1
# 851          852         0       3
# 493          494         0       1
# 96            97         0       1
# 116          117         0       3
# 672          673         0       2
# 745          746         0       1
# 33            34         0       2
# 54            55         0       1
# 280          281         0       3
# 456          457         0       1
# 438          439         0       1
# 545          546         0       1
# 275          276         1       1
# 483          484         1       3
# 570          571         1       2
# 252          253         0       1
# 829          830         1       1
# 555          556         0       1
# 625          626         0       1
# 326          327         0       3
# 170          171         0       1
# 684          685         0       2
# 694          695         0       1
# 587          588         1       1
# ...

# %%
import numpy as np
import matplotlib.pyplot as mat
import seaborn as sns
# %matplotlib inline

# %%
sns.factorplot('Pclass',data=titanic_df,hue='Sex',kind='count')

# %%
sns.factorplot('Sex',data=titanic_df,hue='Pclass',kind='count')

# %%
def male_female_child(passenger):
    age,sex=passenger
    if age < 16:
        return 'child'
    else:
        return sex

# %%
titanic_df['Person']=titanic_df[['Age','Sex']].apply(male_female_child,axis=1)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df2=titanic_df.loc[titanic_df["Age"]<=16]
females=titanic_df.loc[titanic_df['Sex']=='female']

# %%
females
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...

# %%
sns.factorplot('Age',data=df2,hue='Sex',kind="count",aspect=3)

# %%
sns.factorplot('Pclass',data=df2,hue='Sex',kind="count",aspect=3)

# %%
sns.factorplot('Sex',data=females,kind='count',hue='Pclass')

# %%
fig=sns.FaceGrid(titanic_df,hue='Sex',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

oldest=titanic_df['Age'].max()

fig.set(xlim=(0,oldest))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-51eed7a41508> in <module>()
# ----> 1 fig=sns.FaceGrid(titanic_df,hue='Sex',aspect=4)
#       2 fig.map(sns.kdeplot,'Age',shade=True)
#       3
#       4 oldest=titanic_df['Age'].max()
#       5
#
# AttributeError: module 'seaborn' has no attribute 'FaceGrid'

# %%
deck=titanic_df['Cabin'].dropna()

# %%
deck.head()
# Out:
# 1      C85
# 3     C123
# 6      E46
# 10      G6
# 11    C103
# Name: Cabin, dtype: object

# %%
levels=[]

for level in deck:
    levels.append(level[0])

cabin_df=DataFrame(levels)
cabin_df.columns=['Cabin']
cabin_df['Cabin'].values.sort()

sns.factorplot('Cabin',data=cabin_df,palette='winter_d',kind='count')

# %%
cabin_df=cabin_df[cabin_df.Cabin !='T']
cabin_df.dropna()
titanic_df['Deck']=cabin_df['Cabin']
titanic_df.loc[titanic_df['Deck']=='C']
# Out:
#      PassengerId  Survived  Pclass  \
# 62            63         0       1
# 63            64         0       3
# 64            65         0       1
# 65            66         1       3
# 66            67         1       2
# 67            68         0       3
# 68            69         1       3
# 69            70         0       3
# 70            71         0       2
# 71            72         0       3
# 72            73         0       2
# 73            74         0       3
# 74            75         1       3
# 75            76         0       3
# 76            77         0       3
# 77            78         0       3
# 78            79         1       2
# 79            80         1       3
# 80            81         0       3
# 81            82         1       3
# 82            83         1       3
# 83            84         0       1
# 84            85         1       2
# 85            86         1       3
# 86            87         0       3
# ...

# %%
sns.factorplot('Cabin',data=cabin_df,palette='summer',kind='count')

# %%
sns.factorplot('Embarked',data=titanic_df,hue='Pclass',kind='count',order=['C','Q','S'])

# %%
titanic_df["Alone"]=titanic_df.SibSp+titanic_df.Parch

# %%
titanic_df["Alone"].loc[titanic_df["Alone"]>0 ]='With Family'
titanic_df["Alone"].loc[titanic_df["Alone"]==0 ]='Alone'
# Out:
# C:\Users\alnit\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
sns.factorplot('Alone',data=titanic_df,kind='count',palette='summer')

# %%
titanic_df['Survivor']=titanic_df.Survived.map({0:'no',1:'yes'})
sns.factorplot('Survivor',data=titanic_df,kind='count')

# %%
sns.factorplot('Pclass','Survived',data=titanic_df)

# %%
sns.factorplot('Pclass',data=titanic_df,hue='Survived',kind='count')

# %%
sns.factorplot('Pclass','Survived',hue='Person',data=titanic_df)

# %%
sns.lmplot('Age','Survived',data=titanic_df,aspect=2)

# %%
sns.lmplot('Age','Survived',hue='Pclass',data=titanic_df,palette='winter',aspect=3)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
deck_survival_df=titanic_df.loc[:,['Survived','Deck','Person','Pclass']]
deck_survival_df.dropna()
# Out:
#      Survived Deck  Person  Pclass
# 0           0    A    male       3
# 1           1    A  female       1
# 2           1    A  female       3
# 3           1    A  female       1
# 4           0    A    male       3
# 5           0    A    male       3
# 6           0    A    male       1
# 7           0    A   child       3
# 8           1    A  female       3
# 9           1    A   child       2
# 10          1    A   child       3
# 11          1    A  female       1
# 12          0    A    male       3
# 13          0    A    male       3
# 14          0    A   child       3
# 15          1    B  female       2
# 16          0    B   child       3
# 17          1    B    male       2
# 18          0    B  female       3
# 19          1    B  female       3
# 20          0    B    male       2
# 21          1    B    male       2
# 22          1    B   child       3
# 23          1    B    male       1
# 24          0    B   child       3
# 25          1    B  female       3
# ...

# %%
sns.factorplot('Pclass','Survived',hue='Person',data=deck_survival_df)

# %%
sns.factorplot('Alone','Survived',hue='Pclass',data=titanic_df)

# %%
sns.factorplot('Sex',data=titanic_df,hue='Pclass',kind='count')

# %%
sns.lmplot('Survived','Age',data=age_Survival_df,hue='Sex')
